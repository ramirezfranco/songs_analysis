# %%
import util
import json
import nltk
import pandas as pd
# %reload_ext autoreload
# %autoreload 2

# %%
with open('regaetton_songs.json', 'r') as file:
    corpus = json.load(file)

# %%
documents = [d['lyrics'] for artist in corpus.values() for d in artist.values()]

# %%
ners  = util.ners_in_corpus(documents)

# %%
util.ners_frequency(ners, 'CRIMINAL_CHARGE')
# Out:
#                    Frequency
# traición                  53
# tortura                   39
# drogas                    37
# delito                    32
# asalto                    31
# tren                      18
# secuestro                 15
# contrabando                8
# asesinato                  7
# delitos                    7
# homicidio                  4
# acecho                     3
# soborno                    3
# adulterio                  2
# invasión                   2
# fraude                     1
# crimen organizado          1
# espionaje                  1
# explosivos                 1
# terrorismo                 1
# chantaje                   1
# escapar                    1
# abandono                   1
# incesto                    1
# conspiración               1
# perjurio                   1
# robando                    1

# %%
util.ners_frequency(ners, 'CAUSE_OF_DEATH')
# Out:
#                          Frequency
# fuego                          665
# guerra                         245
# veneno                          63
# duelo                           34
# enfermedad                      30
# tormenta                        27
# disparo                         21
# tabaco                          20
# ataque                          17
# violencia                       14
# fuego fuego fuego fuego         12
# desastre                        12
# choque                          12
# explosión                       11
# demencia                        10
# suicidio                        10
# huracán                          9
# terremoto                        6
# fuego fuego                      6
# cáncer                           6
# sobredosis                       5
# cirugía                          5
# plaga                            4
# alzheimer                        3
# que cae                          3
# ataques                          3
# ...

# %%
util.ners_frequency(ners, 'DATE')
# Out:
#                       Frequency
# hoy                        1966
# mañana                      647
# esta noche                  643
# ayer                        281
# domingo                      38
# hoy hoy hoy                  32
# viernes                      29
# lunes                        28
# enero                        26
# diciembre                    23
# hoy hoy                      19
# jueves                       19
# mayo                         17
# el viernes                   16
# el lunes                     11
# martes                        9
# el domingo                    7
# noche                         7
# sábado                        6
# esta                          5
# febrero                       5
# marzo                         4
# octubre                       4
# noviembre                     3
# el 14 de febrero              3
# el jueves                     3
# 14 de febrero                 2
# septiembre                    2
# ...
